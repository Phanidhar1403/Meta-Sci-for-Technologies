# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('country_vaccinations.csv')
print(data)
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 25857     Zimbabwe      ZWE  2021-06-16           1120873.0
# 25858     Zimbabwe      ZWE  2021-06-17           1126087.0
# 25859     Zimbabwe      ZWE  2021-06-18           1131397.0
# 25860     Zimbabwe      ZWE  2021-06-19           1133920.0
# 25861     Zimbabwe      ZWE  2021-06-20           1138733.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
data
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 25857     Zimbabwe      ZWE  2021-06-16           1120873.0
# 25858     Zimbabwe      ZWE  2021-06-17           1126087.0
# 25859     Zimbabwe      ZWE  2021-06-18           1131397.0
# 25860     Zimbabwe      ZWE  2021-06-19           1133920.0
# 25861     Zimbabwe      ZWE  2021-06-20           1138733.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %%
data.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
data.shape
# Out:
# (25862, 15)

# %%
data.info
# Out:
# <bound method DataFrame.info of            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 25857     Zimbabwe      ZWE  2021-06-16           1120873.0
# 25858     Zimbabwe      ZWE  2021-06-17           1126087.0
# 25859     Zimbabwe      ZWE  2021-06-18           1131397.0
# 25860     Zimbabwe      ZWE  2021-06-19           1133920.0
# 25861     Zimbabwe      ZWE  2021-06-20           1138733.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# ...

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.452200e+04       1.376200e+04             1.104100e+04
# mean         9.139252e+06       4.737802e+06             2.681353e+06
# std          4.592776e+07       1.797156e+07             1.093032e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.005620e+05       7.876700e+04             3.719700e+04
# 50%          7.007560e+05       5.149065e+05             2.834740e+05
# 75%          3.241681e+06       2.139073e+06             1.192415e+06
# max          1.029223e+09       6.220000e+08             2.232990e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.200300e+04        2.559500e+04
# mean             2.012910e+05        1.020430e+05
# std              1.122962e+06        7.304361e+05
# min              0.000000e+00        0.000000e+00
# 25%              3.967500e+03        8.400000e+02
# ...

# %%
data.head(1)
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
#
#                                           vaccines                source_name  \
# 0  BBIBP-CorV, Oxford/AstraZeneca, Pfizer/BioNTech  World Health Organization
#
#              source_website
# 0  https://covid19.who.int/

# %%
data.tail(2)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 25860  Zimbabwe      ZWE  2021-06-19           1133920.0           701348.0
# 25861  Zimbabwe      ZWE  2021-06-20           1138733.0           703065.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 25860                 432572.0                  2523.0              4360.0
# 25861                 435668.0                  4813.0              4525.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 25860                            7.63                           4.72
# 25861                            7.66                           4.73
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 25860                                 2.91                           293.0
# 25861                                 2.93                           304.0
#
#                 vaccines         source_name  \
# ...

# %%
data.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     11340
# people_vaccinated                      12100
# people_fully_vaccinated                14821
# daily_vaccinations_raw                 13859
# daily_vaccinations                       267
# total_vaccinations_per_hundred         11340
# people_vaccinated_per_hundred          12100
# people_fully_vaccinated_per_hundred    14821
# daily_vaccinations_per_million           267
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
data.shape
# Out:
# (25862, 15)

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
data.shape
# Out:
# (9502, 15)

# %%
x = data['iso_code'].value_counts()

# %%
data.fillna(x)
# Out:
#            country iso_code        date  total_vaccinations  \
# 94     Afghanistan      AFG  2021-05-27            593313.0
# 101    Afghanistan      AFG  2021-06-03            630305.0
# 152        Albania      ALB  2021-02-18              3049.0
# 234        Albania      ALB  2021-05-11            622507.0
# 235        Albania      ALB  2021-05-12            632676.0
# ...            ...      ...         ...                 ...
# 25857     Zimbabwe      ZWE  2021-06-16           1120873.0
# 25858     Zimbabwe      ZWE  2021-06-17           1126087.0
# 25859     Zimbabwe      ZWE  2021-06-18           1131397.0
# 25860     Zimbabwe      ZWE  2021-06-19           1133920.0
# 25861     Zimbabwe      ZWE  2021-06-20           1138733.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 94              479574.0                 113739.0                  2859.0
# 101             481800.0                 148505.0                  4015.0
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
data['iso_code']
# Out:
# 94       AFG
# 101      AFG
# 152      ALB
# 234      ALB
# 235      ALB
#         ...
# 25857    ZWE
# 25858    ZWE
# 25859    ZWE
# 25860    ZWE
# 25861    ZWE
# Name: iso_code, Length: 9502, dtype: object

# %%
import matplotlib.pyplot as plt

total_vaccinations = data.total_vaccinations.head()
iso_code = data.iso_code.head()
plt.title("total_vaccinations vs iso_code")
plt.xlabel("total_vaccinations")
plt.ylabel("iso_code") #Fixed typo here
plt.plot(total_vaccinations,iso_code,color="red",marker="*") # Changed variables to total_vaccinations and iso_code
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
