# %%
class Student:
    def __init__(self):
        self.students = {}
    def add_student(self):
        student_id = input("Enter Student ID: ")
        if student_id in self.students:
            print("Student ID already exists.")
            return
        name = input("Enter Name: ")
        age = int(input("Enter Age: "))
        grade = input("Enter Grade: ")
        self.students[student_id] = {"name": name, "age": age, "grade": grade}
        print("Student added successfully.")
    def display_students(self):
        if not self.students:
            print("No student records available.")
        else:
            for student_id, details in self.students.items():
                print(f"ID: {student_id}, Name: {details['name']}, Age: {details['age']}, Grade: {details['grade']}")
    def search_student(self):
        student_id = input("Enter Student ID to search: ")
        if student_id in self.students:
            details = self.students[student_id]
            print(f"ID: {student_id}, Name: {details['name']}, Age: {details['age']}, Grade: {details['grade']}")
        else:
            print("Student not found.")
    def delete_student(self):
        student_id = input("Enter Student ID to delete: ")
        if student_id in self.students:
            del self.students[student_id]
            print("Student deleted successfully.")
        else:
            print("Student ID not found.")
    def update_student(self):
        student_id = input("Enter Student ID to update: ")
        if student_id in self.students:
            name = input("Enter new Name (leave blank to skip): ")
            age = input("Enter new Age (leave blank to skip): ")
            grade = input("Enter new Grade (leave blank to skip): ")
            if name:
                self.students[student_id]["name"] = name
            if age:
                self.students[student_id]["age"] = int(age)
            if grade:
                self.students[student_id]["grade"] = grade
            print("Student details updated successfully.")
        else:
            print("Student ID not found.")
    def run(self):
        while True:
            print("\n1. Add Student\n2. Display Students\n3. Search Student\n4. Delete Student\n5. Update Student\n6. Exit")
            choice = input("Enter your choice: ")

            if choice == '1':
                self.add_student()
            elif choice == '2':
                self.display_students()
            elif choice == '3':
                self.search_student()
            elif choice == '4':
                self.delete_student()
            elif choice == '5':
                self.update_student()
            elif choice == '6':
                print("Exiting...")
                break
            else:
                print("Invalid choice. Please try again.")
if __name__ == "__main__":
    student_management = Student()
    student_management.run()
# Out:
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Delete Student
# 5. Update Student
# 6. Exit
# Enter your choice: 1
# Enter Student ID: 192
# Enter Name: phani
# Enter Age: 21
# Enter Grade: btech
# Student added successfully.
#
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Delete Student
# 5. Update Student
# 6. Exit
# Enter your choice: 2
# ID: 192, Name: phani, Age: 21, Grade: btech
#
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Delete Student
# 5. Update Student
# 6. Exit
# Enter your choice: 3
# Enter Student ID to search: 192
# ID: 192, Name: phani, Age: 21, Grade: btech
#
# 1. Add Student
# 2. Display Students
# 3. Search Student
# 4. Delete Student
# 5. Update Student
# 6. Exit
# Enter your choice: 5
# Enter Student ID to update: 192
# Enter new Name (leave blank to skip):
# Enter new Age (leave blank to skip): 20
# Enter new Grade (leave blank to skip):
# Enter your choice:
# Student details updated successfully.
#
# ...

# %%
class Nokia1:
    def __init__(self):
        self.features = ["Calling", "SMS"]
    def show_features(self):
        print("Nokia1 Features: {}".format(", ".join(self.features)))
    def call(self):
        print("Calling feature available.")
    def sms(self):
        print("SMS feature available.")
class Nokia2(Nokia1):
    def __init__(self):
        super().__init__()
        self.features.append("Camera")
    def show_features(self):
        print("Nokia2 Features: {}".format(", ".join(self.features)))
    def camera(self):
        print("Camera feature added.")
class Nokia3(Nokia2):
    def __init__(self):
        super().__init__()
        self.features.append("Internet")
    def show_features(self):
        print("Nokia3 Features: {}".format(", ".join(self.features)))
    def internet(self):
        print("Internet browsing feature added.")
class Nokia4(Nokia3):
    def __init__(self):
        super().__init__()
        self.features.append("Touchscreen")

    def show_features(self):
        print("Nokia4 Features: {}".format(", ".join(self.features)))

    def touchscreen(self):
        print("Touchscreen feature added.")
nokia1 = Nokia1()
nokia1.show_features()
nokia1.call()
nokia1.sms()

nokia2 = Nokia2()
nokia2.show_features()
nokia2.call()
nokia2.sms()
nokia2.camera()

nokia3 = Nokia3()
nokia3.show_features()
nokia3.call()
nokia3.sms()
nokia3.camera()
nokia3.internet()

nokia4 = Nokia4()
nokia4.show_features()
nokia4.call()
nokia4.sms()
nokia4.camera()
nokia4.internet()
nokia4.touchscreen()
# Out:
# Nokia1 Features: Calling, SMS
# Calling feature available.
# SMS feature available.
# Nokia2 Features: Calling, SMS, Camera
# Calling feature available.
# SMS feature available.
# Camera feature added.
# Nokia3 Features: Calling, SMS, Camera, Internet
# Calling feature available.
# SMS feature available.
# Camera feature added.
# Internet browsing feature added.
# Nokia4 Features: Calling, SMS, Camera, Internet, Touchscreen
# Calling feature available.
# SMS feature available.
# Camera feature added.
# Internet browsing feature added.
# Touchscreen feature added.
